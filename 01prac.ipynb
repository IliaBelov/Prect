# %% [markdown]
# <a href="https://colab.research.google.com/github/IliaBelov/Prect/blob/main/01prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1. Аналитическое (выполняется в тетради)

# %% [markdown]
# ###1.1 Вычислите производную заданной функции:

# %% [markdown]
# 1. $y(x)=2x^2-3x+1$
# 2. $y(x)=3x^2+x-1$
# 3. $y(x)=-2x^2-x+4$
# 4. $y(x)=x^2+4x+2$
# 5. $y(x)=-3x^2-3x+4$
# 6. $y(x)=4x^2-2x-1$
# 7. $y(x)=5x^2+x+3$
# 8. $y(x)=-x^2-4x+5$
# 9. $y(x)=-4x^2+4x-1$
# 10. $y(x)=-2x^2+6x+5$
# 11. $y(x)=-5x^2+x-4$
# 12. $y(x)=4x^2+2x+1$

# %% [markdown]
# ###1.2 Вычислите производную заданной функции:

# %% [markdown]
# 1. $y(x)=e^{-x}\cdot\sin{4x}$
# 2. $y(x)=e^{2x}\cdot\cos{(x+1)}$
# 3. $y(x)=e^{-x}\cdot\sqrt{x-2}$
# 4. $y(x)=e^{-2x}\cdot\sin{(2x-2)}$
# 5. $y(x)=e^{2x}\cdot\cos{3x}$
# 6. $y(x)=e^{x}\cdot\sqrt{2x+1}$
# 7. $y(x)=e^{-3x}\cdot\ln{(4x)}$
# 8. $y(x)=e^{-2x}\cdot\sin{(2-x)}$
# 9. $y(x)=e^{-x}\cdot\cos{(1-2x)}$
# 10. $y(x)=e^{x}\cdot\sqrt{4x+2}$
# 11. $y(x)=e^{2x}\cdot\ln{(1-x)}$
# 12. $y(x)=e^{-2x}\cdot\ln{(3+2x)}$

# %% [markdown]
# ###1.3 Вычислите производную заданной функции:

# %% [markdown]
# 1. $x(t)=\sin(e^{2t})$
# 2. $x(t)=\sqrt{\sin{3t}}$
# 3. $x(t)=e^{\cos(1-t)}$
# 4. $x(t)=\ln(1+4t^3)$
# 5. $x(t)=\tan(1/(t^2-t))$
# 6. $x(t)=\cos(\ln(1-2t))$
# 7. $x(t)=\sin^3(t^2+t)$
# 8. $x(t)=\arcsin(\sqrt{t})$
# 9. $x(t)=2^{t^3-4t^2}$
# 10. $x(t)=\sin(\cos{2t})$
# 11. $x(t)=\ln(1+e^{-t})$
# 12. $x(t)=\arccos(1-t^2)$

# %% [markdown]
# ###1.4 Вычислите неопределенный интеграл от заданной функции:

# %% [markdown]
# 1. $y(x)=2x+3$
# 2. $y(x)=4-x$
# 3. $y(x)=3x-1$
# 4. $y(x)=2-3x$
# 5. $y(x)=5x+2$
# 6. $y(x)=-2x+4$
# 7. $y(x)=6x-3$
# 8. $y(x)=1-4x$
# 9. $y(x)=5+2x$
# 10. $y(x)=1-4x$
# 11. $y(x)=-x+5$
# 12. $y(x)=6-2x$

# %% [markdown]
# ###1.5 Вычислите определенный интеграл:

# %% [markdown]
# 1. $\int_0^1 e^{6x-3}dx$
# 2. $\int_0^\pi \sin(1-4x)dx$
# 3. $\int_1^2 \cos(5+2x)dx$
# 4. $\int_{-1}^0 dx/(1-4x)$
# 5. $\int_1^4 \sqrt{5-x}dx$
# 6. $\int_0^3 e^{6-2x}dx$
# 7. $\int_0^1 \cos(2x+3)dx$
# 8. $\int_0^4 \sin(4-x)dx$
# 9. $\int_1^2 dx/(3x-1)$
# 10. $\int_{-1}^0 dx/\sqrt{2-3x}$
# 11. $\int_1^4 e^{5x+2}dx$
# 12. $\int_0^2 \sin(-2x+4)dx$

# %% [markdown]
# ###1.6 Найдите общее решение простейшего дифференциального уравнения и решите соответствующую начальную задачу:

# %% [markdown]
# 1. $y'x=1$, $y(e)=2$
# 2. $y'-x^2=x$, $y(1)=-1$
# 3. $2y'=x+\sin{3x}$, $y(\pi)=0$
# 4. $(x+1)y'=2$, $y(0)=-1$
# 5. $y'+x^3=1$, $y(-1)=2$
# 6. $xy'=x^2+1$, $y(1)=4$
# 7. $y'x^2=1-x$, $y(1)=0$
# 8. $y'-\cos{x}=x+1$, $y(0)=1$
# 9. $y'+x^3=\sin{3x}$, $y(0)=0$
# 10. $y'x=\sqrt{x}-x^2$, $y(4)=1$
# 11. $y'-3x^2=\cos{x}$, $y(\pi)=0$
# 12. $\sqrt{x}y'=1+2x^2$, $y(9)=-1$

# %% [markdown]
# ##Задание 2. Производные, интегралы в SymPy

# %% [markdown]
# ###Пример оформления решения

# %% [markdown]
# Подключаем пакеты Python

# %%
from sympy import * # пакет  символьных вычислений
import numpy as np # пакет для работы с многомерными массивами

# %% [markdown]
# Создаем символы (переменные)

# %%
x, y, t, C = symbols("x y t C")

# %% [markdown]
# Теперь можно создавать выражения с этими переменными

# %%
f = x ** 2 - sin(x) / 2 + sqrt(x - 1)
f
# Out:
# x**2 + sqrt(x - 1) - sin(x)/2

# %% [markdown]
# Дифференцирование выражений выполняется командой diff

# %%
diff(f, x)
# Out:
# 2*x - cos(x)/2 + 1/(2*sqrt(x - 1))

# %% [markdown]
# Интегрирование - командой integrate

# %%
integrate(f, x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f992ad274d12> in <module>()
# ----> 1 integrate(f, x)
#
# NameError: name 'integrate' is not defined

# %% [markdown]
# Определенный интеграл вычисляется той же командой, но с указанием во втором аргументе пределов интегрирования

# %%
integrate(f, (x, 2, 5))
# Out:
# cos(5)/2 - cos(2)/2 + 131/3

# %% [markdown]
# Решим простейшее дифференциальное уравнение $xy'+2=x^2$ с начальным условием $y(1)=2$

# %%
# создаем производную 
dydx = Derivative(y, x) # dydx - имя переменной, обозначающей производную
dydx
# Out:
# Derivative(y, x)

# %%
# создаем уравнение, функция Eq(a, b) обозначает равенство a = b
eq = Eq(x * dydx + 2, x ** 2)
eq
# Out:
# Eq(x*Derivative(y, x) + 2, x**2)

# %%
# находим производную с помощью команды solve - решение алгебраических уравнений, результат - список решений, выбор нужного решения через индексирование
sol = solve(eq, dydx)[0]
sol
# Out:
# x - 2/x

# %%
# интегрируем найденную производную и вручную добавляем константу интегрирования - получаем общее решение заданного ДУ
dsol = integrate(sol, x) + C
dsol
# Out:
# C + x**2/2 - 2*log(x)

# %%
# Находим константу интегрирования, решая уравнение y(x0, C) = y0, где x0, y0 - начальное условие
x0, y0 = 1, 2 # см. условие задачи выше
X = dsol.subs(x, x0) # подставили x0 вместо x в решение dsol
eq = Eq(y0, X) # приравняли к y0
C0 = solve(eq)[0] # нашли С
dsol0 = dsol.subs(C, C0) # подставили C в общее решение
dsol0 # решение начальной задачи
# Out:
# x**2/2 - 2*log(x) + 3/2

# %% [markdown]
# Построим графики с интегральными кривыми

# %%
# график функции f(x) в интервале от a до b строится командой plot( f(x), (x,a,b) )
p = plot(x ** 2, (x, -1, 1))

# %%
# график решения dsol0 начальной задачи
p = plot(dsol0, (x, 0.1, 4))

# %%
# график семейства интегральных кривых общего решения dsol
p = plot(show=False) # пустой график
for c in np.arange(-2, 2, 0.25): # цикл по значениям константы C
  p1 = plot(dsol.subs(C, c), (x, 0.1, 4), show=False) # график новой кривой
  p.extend(p1) # добавляем новый график к общему графику
p.show() # показываем общий график

# %% [markdown]
# ### Задание
# По описанной выше схеме вычислите производные упражнений 1.1 - 1.3 из аналитической части

# %% [markdown]
# Вычислите интегралы 1.4 - 1.5 из аналитической части

# %% [markdown]
# Решите простейшее ДУ из упражнения 1.6 из аналитической части (общее решение и решение начальной задачи)

# %% [markdown]
# ## Задание 3. Свободное падение тел (модели 1-3 в лекции)

# %% [markdown]
# Создаем переменные $x$, $y$, $t$, $w_0$, $\alpha$ и $g$

# %%
from sympy import * # пакет  символьных вычислений
import numpy as np # пакет для работы с многомерными массивами

# %%
x, y, t , w0, a, g = symbols("x y t w0 a g")

# %% [markdown]
# Создаем начальные условия $x_0=0$, $y_0=0$, $u_0=w_0\cos{\alpha}$, $v_0=w_0\sin{\alpha}$

# %%
x0 = 0
y0 = 0
u0 = w0 * cos(a)
v0 = w0 * sin(a)

# %% [markdown]
# Создаем правые части простейших дифференциальных уравнений для горизонтальной и вертикальной скоростей: $$du/dt=0, dv/dt=-g$$

# %%
U = 0
V = -g

# %% [markdown]
# Интегрируем эти правые части и находим сами скорости с учетом начальных условий: $$u=\int U dt + u_0, v = \int V dt + v_0$$

# %%
u = integrate(U,t) + u0
v = integrate(V,t) + v0
u, v # выводим на экран найденные интегралы
# Out:
# (w0*cos(a), -g*t + w0*sin(a))

# %% [markdown]
# Получили правые части простейших ДУ для $x(t)$ и $y(t)$: $dx/dt=u$, $dy/dt=v$. Интегрируем эти выражения и находим $x(t)$ и $y(t)$ с учетом начальных условий: $$x=\int u dt + x_0, y=\int v dt + y0$$

# %%
xsol = integrate(u,t) + x0
ysol = integrate(v,t) + y0
xsol, ysol # выводим на экран найденные интегралы
# Out:
# (t*w0*cos(a), -g*t**2/2 + t*w0*sin(a))

# %% [markdown]
# Вычисляем время $t_1$ от начала полета до падения, решая уравнение $y(t)=0$. Выражение $y(t)$ хранится в переменной ysol. Данное уравнение имеет два решения, нужно записать в переменную t1 ненулевое решение.

# %%
t1 = solve(Eq(ysol,0),t)[1]
t1 # вывод на экран
# Out:
# 2*w0*sin(a)/g

# %% [markdown]
# Находим $x$-координату точки падения, подставляя найденное выше значение $t_1$ в выражение $x(t)$ (переменная xsol):

# %%
x1 = xsol.subs(t,t1)
x1 # вывод на экран
# Out:
# 2*w0**2*sin(a)*cos(a)/g

# %% [markdown]
# Выражаем $y$ через $x$, исключая из системы $x(t)=0$, $y(t)=0$ время $t$:

# %%
T = solve(Eq(xsol, x), t)[0] # выразили t через x
Y = ysol.subs(t, T) # подставили T в y(t) вместо t
Y # вывод формулы на экран
# Out:
# -g*x**2/(2*w0**2*cos(a)**2) + x*sin(a)/cos(a)

# %% [markdown]
# Строим траекторию движения тела от точки броска $x=0$ до точки падения $x=x_1$ для ускорения свободного падения $g=9.8$, начальной скорости $w_0=1$, угла $\alpha=\pi/4$:

# %%
ya = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/4) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/4) # точка падения
p = plot(ya, (x, 0, x1a))

# %% [markdown]
# Постройте на том же графике аналогичную траекторию полета тела на заданном космическом теле (ускорение свободного падения для этого тела найдите в Интернете):
# 1. Меркурий
# 2. Венера
# 3. Луна
# 4. Марс
# 5. Юпитер
# 6. Ио
# 7. Сатурн
# 8. Титан
# 9. Уран
# 10. Нептун
# 11. Плутон
# 12. Харон

# %%
ya1 = Y.subs(g, 1.62).subs(w0, 1).subs(a, np.pi/4) # уравнение траектории
x1a = x1.subs(g, 1.62).subs(w0, 1).subs(a, np.pi/4) # точка падения
p = plot(ya, (x, 0, x1a))

# %%
mer = Y.subs(g, 3.7).subs(w0, 1).subs(a, np.pi/4) # уравнение траектории
x1a = x1.subs(g, 3.7).subs(w0, 1).subs(a, np.pi/4) # точка падения
p = plot(mer, (x, 0, x1a))

# %%
ven = Y.subs(g, 8.9).subs(w0, 1).subs(a, np.pi/4) # уравнение траектории
x1a = x1.subs(g, 8.9).subs(w0, 1).subs(a, np.pi/4) # точка падения
p = plot(ven, (x, 0, x1a))

# %%
upit = Y.subs(g, 24.7).subs(w0, 1).subs(a, np.pi/4) # уравнение траектории
x1a = x1.subs(g, 24.7).subs(w0, 1).subs(a, np.pi/4) # точка падения
p = plot(upit, (x, 0, x1a))

# %%
sat = Y.subs(g, 9).subs(w0, 1).subs(a, np.pi/4) # уравнение траектории
x1a = x1.subs(g, 9).subs(w0, 1).subs(a, np.pi/4) # точка падения
p = plot(sat, (x, 0, x1a))

# %%
sat = Y.subs(g, 8.7).subs(w0, 1).subs(a, np.pi/4) # уравнение траектории
x1a = x1.subs(g, 8.7).subs(w0, 1).subs(a, np.pi/4) # точка падения
p = plot(sat, (x, 0, x1a))

# %%
nep = Y.subs(g, 11).subs(w0, 1).subs(a, np.pi/4) # уравнение траектории
x1a = x1.subs(g, 11).subs(w0, 1).subs(a, np.pi/4) # точка падения
p = plot(nep, (x, 0, x1a))

# %%
p1 = 
p.extend(p1)
p.show()

# %% [markdown]
# Постройте семейство траекторий для разных начальных углов $\alpha\in[\pi/20, \pi/2]$ с шагом $\pi/20$ для вашего космического тела:

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20+np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %% [markdown]
# Постройте семейство траекторий для разных начальных скоростей $w_0\in[1,10]$ с шагом $1$ для вашего космического тела

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 1).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 2).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 2).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 3).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 3).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 4).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 4).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 5).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 5).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 6).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 6).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 7).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 7).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 8).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 8).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 9).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 9).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))

# %%
ya1 = Y.subs(g, 9.8).subs(w0, 10).subs(a, np.pi/20) # уравнение траектории
x1a = x1.subs(g, 9.8).subs(w0, 10).subs(a, np.pi/20) # точка падения
p = plot(ya1, (x, 0, x1a))
